# %% [markdown]
# # Environment Setup
# #### Name : Venkata Sai Pradyumna Nadella
# #### UID : 122096059
#
# ### Step 3. Setting up Google Colab
# Google Colab (https://colab.research.google.com/) is a cloud-based environment that will be useful for running more extensive computations without stressing your local machine. Ensure that you can access Google Colab through your Google account. Create a simple notebook, run a Python cell, and confirm it works. For more details, check the tutorial: https://colab.research.google.com/drive/16pBJQePbqkz3QFV54L4NIkOn1kwpuRrj

# %%
# Is my colab setup done and is it working?

ques = input("Is your colab setup done and is it working? (yes/no) : ")
if ques == "yes":
  print("Congratulation! Your colab is all set for coding!!")
else:
  print("Please set up your colab ASAP!!")
# Out:
# Is your colab setup done and is it working? (yes/no) : yes
# Congratulation! Your colab is all set for coding!!

# %%
import pandas as pd
import numpy as np

a=np.array([1,2])
b=np.array([4,5])
df_1 = pd.DataFrame(a, columns=['A'])
df_2 = pd.DataFrame(b, columns=['B'])
df = pd.concat([df_1, df_2], axis=1)
df
# Out:
#    A  B
# 0  1  4
# 1  2  5

# %% [markdown]
# # Pytorch Setup

# %%
# !pip install torch torchvision

# %%
import torch
# Name : Venkata Sai Pradyumna Nadella
# UID  : 122096059
print("PyTorch Version: ", torch.version)
print("GPU Available: ", torch.cuda.is_available())
# Out:
# PyTorch Version:  <module 'torch.version' from '/usr/local/lib/python3.12/dist-packages/torch/version.py'>
# GPU Available:  False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import torch
print("Name : Venkata Sai Pradyumna Nadella\n", "UID  : 122096059")
print("PyTorch Version: ", torch.version)
print("GPU Available: ", torch.cuda.is_available())
# Out:
# Name : Venkata Sai Pradyumna Nadella
#  UID  : 122096059
# PyTorch Version:  <module 'torch.version' from '/usr/local/lib/python3.12/dist-packages/torch/version.py'>
# GPU Available:  True

# %%
print("Name : Venkata Sai Pradyumna Nadella\n", "UID  : 122096059")
if torch.cuda.is_available():
    print("PyTorch Version: ", torch.version)
    print("PyTorch Version: ", torch.__version__)
    print("CUDA available:", torch.cuda.is_available())
    print("Number of GPUs:", torch.cuda.device_count())
    print("Current GPU:", torch.cuda.current_device())
    print("GPU Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("No CUDA device available")
# Out:
# Name : Venkata Sai Pradyumna Nadella
#  UID  : 122096059
# PyTorch Version:  <module 'torch.version' from '/usr/local/lib/python3.12/dist-packages/torch/version.py'>
# PyTorch Version:  2.8.0+cu126
# CUDA available: True
# Number of GPUs: 1
# Current GPU: 0
# GPU Name: Tesla T4
