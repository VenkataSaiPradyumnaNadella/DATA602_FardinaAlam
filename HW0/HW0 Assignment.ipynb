# %% [markdown]
# This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.
#
# The goal is to write a function to count the frequency of different characters in a given string. For example: character_frequency('google') should return a `dict`: {'g': 2, 'o': 2, 'l': 1, 'e': 1}.
#
# There are many tutorials on the web that can show you how to use the Python data structures. Quite a few examples at: https://docs.python.org/3/tutorial/datastructures.html
#
#
# You should edit the function definition below, make sure to press 'Shift + Enter' to execute it, and then execute the two function calls to check that the output is correct.

# %%
def character_frequency(s):
    ret = dict()
    for ele in s:
        if ele in ret:
            ret[ele] += 1
        else:
            ret[ele] = 1
    return ret

# %%
print(character_frequency('google'))
print(character_frequency('DATA602'))
# Out:
# {'g': 2, 'o': 2, 'l': 1, 'e': 1}
# {'D': 1, 'A': 2, 'T': 1, '6': 1, '0': 1, '2': 1}

# %%
character_frequency('This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.')
# Out:
# {'T': 1,
#  'h': 2,
#  'i': 6,
#  's': 7,
#  ' ': 15,
#  'a': 5,
#  'g': 1,
#  'n': 6,
#  'm': 2,
#  'e': 10,
#  't': 10,
#  'd': 4,
#  'o': 6,
#  'u': 4,
#  'r': 3,
#  'y': 2,
#  'b': 3,
#  'l': 1,
#  'J': 1,
#  'p': 1,
#  'N': 1,
#  'k': 1,
#  '.': 1}

# %% [markdown]
# In Below, Provide GitHub Repository URL:

# %% [markdown]
# GitHub Repo URL (Venkata Sai Pradyumna Nadella) : https://github.com/nvspradyumna/DATA602_FardinaAlam

# %% [markdown]
# In Below, GitHub Page URL:

# %% [markdown]
# GitHub Repo Page URL : https://nvspradyumna.github.io/DATA602_FardinaAlam

# %% [markdown]
# Below, add the screenshots. You can include additional markdown or text cells if needed.

# %% [markdown]
# #### Made use of dev branch and created pull requests to merge into main branch
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Jupyter Notebook and Jupyter lab are setup and working
# #### I am able to access it from http://localhost:8888
# #### Jupyter Notebook
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# #### Jupyter Lab
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Google Colab is also setup and its working
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PyTorch Installation is also done
#
# - Command used : pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# - Also made use of virtual environment to install packages and run python code using it
#
# ##### CUDA Check in Local Machine
# ![image-2.png](attachment:image-2.png)
#
# ##### CUDA Check in Google Colab
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## OPTIONAL

# %% [markdown]
# ### Docker is also setup.
#
# #### Command(windows) : docker run -it -v %cd%\project0:/home/jovyan/notebooks --rm -p 8888:8888 jmct/cmsc320
# ![image-2.png](attachment:image-2.png)
#
# #### URL on with Jupyter Lab is running : http://127.0.0.1:8888/lab?token=4f27fc428b2cd4e08754acb8b5f8396cf24243d6cdeb62c6
# ![image-5.png](attachment:image-5.png)
#
# #### Docker Desktop : Active Container
# ![image-3.png](attachment:image-3.png)
#
# #### Docker Run information
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Using Jupyter notebooks from VS code is also setup.
# ##### Clones the given repository : https://github.com/jlorich/ml-devcontainer.git
# ![image.png](attachment:image.png)
